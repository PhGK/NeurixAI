# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from druxai.utils.gnn_utils import create_pytorch_geometric_graph_data_list_from_smiles, save_dictionary
import pandas as pd

# %%
smiles_df = pd.read_csv("/Users/niklaskiermeyer/Desktop/Codespace/DruxAI/data/preprocessed/unique_drugs_and_smiles.csv",
                        index_col=0)

# %%
embeddings = create_pytorch_geometric_graph_data_list_from_smiles(smiles_df["smiles"].to_list(),
                                                                  drug_names=smiles_df["DRUG"].to_list())

# %%
save_dictionary(embeddings, "/Users/niklaskiermeyer/Desktop/Codespace/DruxAI/data/preprocessed/drug_gnn_embeddings.pt")

# %%
embeddings
# Out:
# {'CYTARABINE': Data(x=[17, 79], edge_index=[2, 36], edge_attr=[36, 10]),
#  'EPINASTINE': Data(x=[19, 79], edge_index=[2, 44], edge_attr=[44, 10]),
#  'FLOXURIDINE': Data(x=[17, 79], edge_index=[2, 36], edge_attr=[36, 10]),
#  'VALRUBICIN': Data(x=[51, 79], edge_index=[2, 110], edge_attr=[110, 10]),
#  'ADAPALENE': Data(x=[31, 79], edge_index=[2, 72], edge_attr=[72, 10]),
#  'METHYLPHENIDATE': Data(x=[17, 79], edge_index=[2, 36], edge_attr=[36, 10]),
#  'FULVESTRANT': Data(x=[41, 79], edge_index=[2, 88], edge_attr=[88, 10]),
#  'ESTRAMUSTINE-PHOSPHATE': Data(x=[33, 79], edge_index=[2, 72], edge_attr=[72, 10]),
#  'MASITINIB': Data(x=[36, 79], edge_index=[2, 80], edge_attr=[80, 10]),
#  'BELINOSTAT': Data(x=[22, 79], edge_index=[2, 46], edge_attr=[46, 10]),
#  'ROMIDEPSIN': Data(x=[36, 79], edge_index=[2, 74], edge_attr=[74, 10]),
#  'METOXIBUTROPATE': Data(x=[23, 79], edge_index=[2, 48], edge_attr=[48, 10]),
#  'OCTOPAMINE': Data(x=[11, 79], edge_index=[2, 22], edge_attr=[22, 10]),
# ...
